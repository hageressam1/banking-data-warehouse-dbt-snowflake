# %% [markdown]
# # Banking Transactions Exploration
#
# ## Objective
# This notebook explores the raw banking transactions dataset before building the data warehouse models.
#
# The goal is to:
# - Understand the dataset structure
# - Identify data quality issues
# - Prepare columns for modeling
# - Validate candidate keys

# %% [markdown]
# ## Data Loading

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4a41d4de-c223-462a-b353-ead35a1154e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a41d4de-c223-462a-b353-ead35a1154e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Banking_Transactions_USA_2023_2024.csv')
df.head()

# %% [markdown]
# ## Dataset Overview
# Check structure, data types, and statistical summary.

# %%
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5389 entries, 0 to 5388
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Transaction_ID           5389 non-null   object
#  1   Account_Number           5389 non-null   object
#  2   Transaction_Date         5389 non-null   object
#  3   Transaction_Amount       5389 non-null   float64
#  4   Merchant_Name            5389 non-null   object
#  5   Transaction_Type         5389 non-null   object
#  6   Category                 5389 non-null   object
#  7   City                     5389 non-null   object
#  8   Country                  5389 non-null   object
#  9   Payment_Method           5389 non-null   object
#  10  Customer_Age             5389 non-null   int64
#  11  Customer_Gender          5389 non-null   object
#  12  Customer_Occupation      5389 non-null   object
#  13  Customer_Income          5389 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Transaction_Amount  Customer_Age  Customer_Income  Account_Balance  \
# count         5389.000000   5389.000000      5389.000000      5389.000000
# mean          2504.649200     44.023567     85802.754023     10096.510087
# std           1426.745115     15.239148     37343.604534      5732.846891
# min              5.460000     18.000000     20028.940000       101.720000
# 25%           1283.340000     31.000000     53809.800000      5159.450000
# 50%           2521.670000     44.000000     85636.380000     10077.780000
# 75%           3715.920000     57.000000    118092.640000     15076.010000
# max           4999.540000     70.000000    149970.500000     19993.040000
#
#        Loyalty_Points_Earned
# count            5389.000000
# mean              249.897384
# std               145.378373
# min                 0.000000
# 25%               122.000000
# 50%               251.000000
# 75%               377.000000
# max               500.000000

# %%
df.head()

# %% [markdown]
# ## Missing Values Analysis

# %%
df.isna().any().any()
# Out:
# np.False_

# %%
df['City'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Uniqueness & Duplicate Validation

# %%
df['Account_Number'].is_unique
# Out:
# True

# %%
df['Transaction_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Categorical Columns Exploration
# Inspect unique values before standardization.

# %%
df['Transaction_Status'].value_counts()
# Out:
# Transaction_Status
# Pending    1811
# Failed     1789
# Success    1789
# Name: count, dtype: int64

# %%
df['Transaction_Status'].unique()
# Out:
# array(['Failed', 'Pending', 'Success'], dtype=object)

# %%
df['Customer_Gender'].unique()
# Out:
# array(['Others', 'Male', 'Female'], dtype=object)

# %%
df['Payment_Method'].unique()
# Out:
# array(['Online Transfer', 'Debit Card', 'E-Wallet', 'Credit Card', 'Cash'],
#       dtype=object)

# %%
df['Transaction_Type'].unique()
# Out:
# array(['Debit', 'Credit'], dtype=object)
